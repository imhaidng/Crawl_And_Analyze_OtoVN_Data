# %%
import pandas as pd

# %%
df = pd.read_csv('data_processed1.csv')
df
# Out:
#                Giá  Năm sản xuất     Kiểu dáng    Xuất xứ  Số km đã đi  \
# 0     1.119000e+09          2016         Sedan  Trongnước      51499.0
# 1     1.789000e+09          2021           SUV   Nhậpkhẩu       8000.0
# 2     5.200000e+08          2021           MPV   Nhậpkhẩu      10000.0
# 3     3.200000e+08          2009         Sedan  Trongnước      90000.0
# 4     7.300000e+08          2016           SUV  Trongnước      68000.0
# ...            ...           ...           ...        ...          ...
# 2291  6.420000e+08          2018  Pick-upTruck   Nhậpkhẩu      15000.0
# 2292  8.980000e+08          2018         Sedan  Trongnước      50000.0
# 2293  3.800000e+08          2014     Hatchback   Nhậpkhẩu      92000.0
# 2294  1.270000e+08          1993         Sedan   Nhậpkhẩu      68000.0
# 2295  5.650000e+08          2016           SUV   Nhậpkhẩu       6000.0
#
#         Hộp số Nhiên liệu
# 0     Sốtựđộng       Xăng
# 1     Sốtựđộng       Xăng
# 2        Sốtay       Xăng
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2296 entries, 0 to 2295
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Giá           2296 non-null   float64
#  1   Năm sản xuất  2296 non-null   int64
#  2   Kiểu dáng     2296 non-null   object
#  3   Xuất xứ       2296 non-null   object
#  4   Số km đã đi   2296 non-null   float64
#  5   Hộp số        2296 non-null   object
#  6   Nhiên liệu    2296 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 125.7+ KB

# %%
import tkinter as tk
from tkinter import messagebox
from tkinter import ttk
import pandas as pd
import joblib
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from datetime import datetime

# Đọc dữ liệu
data = pd.read_csv("data_processed1.csv")

# Phát hiện và xử lý ngoại lệ
Q1 = data['Giá'].quantile(0.3)
Q3 = data['Giá'].quantile(0.66)
IQR = Q3 - Q1
lower_bound = Q1 - 1.9 * IQR
upper_bound = Q3 + 0.9 * IQR

# Thay thế ngoại lệ bằng giá trị trung vị của biến
data['Giá'] = data['Giá'].apply(lambda x: x if lower_bound <= x <= upper_bound else data['Giá'].median())

# Tách biến đặc trưng và biến mục tiêu
X = data.drop(columns='Giá')
y = data['Giá']

# Định nghĩa cột dữ liệu số và phân loại
numerical_cols = ['Số km đã đi']
categorical_cols = ['Năm sản xuất', 'Kiểu dáng', 'Xuất xứ', 'Hộp số', 'Nhiên liệu']

# Tiền xử lý cho dữ liệu số
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# Tiền xử lý cho dữ liệu phân loại
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Gộp tiền xử lý cho dữ liệu số và phân loại
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# Định nghĩa mô hình
model = RandomForestRegressor(random_state=10)

# Tạo pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('model', model)])

# Chia dữ liệu thành tập huấn luyện và kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.14, random_state=39)

# Huấn luyện mô hình
pipeline.fit(X_train, y_train)

# Dự đoán
y_pred = pipeline.predict(X_test)

# Đánh giá mô hình
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R^2 Score: {r2}")

Lưu mô hình đã huấn luyện
joblib.dump(pipeline, 'car_price_model.pkl')
# Out:
# Mean Absolute Error (MAE): 41109833.78207731
# Mean Squared Error (MSE): 6996948948130698.0
# Root Mean Squared Error (RMSE): 83647767.14372416
# R^2 Score: 0.7252235834686278

# %%
import tkinter as tk
from tkinter import messagebox
from tkinter import ttk
import pandas as pd
import joblib
from datetime import datetime

# Load mô hình đã lưu
model = joblib.load('car_price_model.pkl')

# Hàm dự đoán giá xe
def predict():
    try:
        # Kiểm tra năm sản xuất
        year = year_entry.get()
        if not year:
            raise ValueError("Vui lòng nhập năm sản xuất.")
        year = int(year)
        current_year = datetime.now().year
        if not (1987 <= year <= current_year):
            raise ValueError("Năm sản xuất phải từ 1987 đến năm hiện tại.")

        # Kiểm tra số km đã đi
        km_driven = km_driven_entry.get()
        if not km_driven:
            raise ValueError("Vui lòng nhập số km đã đi.")
        km_driven = float(km_driven)

        # Kiểm tra các ô dữ liệu khác
        car_type = car_type_combobox.get()
        if not car_type:
            raise ValueError("Vui lòng chọn kiểu dáng.")
        
        origin = origin_combobox.get()
        if not origin:
            raise ValueError("Vui lòng chọn xuất xứ.")
        
        gearbox = gearbox_combobox.get()
        if not gearbox:
            raise ValueError("Vui lòng chọn hộp số.")
        
        fuel = fuel_combobox.get()
        if not fuel:
            raise ValueError("Vui lòng chọn nhiên liệu.")
        
        # Tạo mảng đầu vào cho mô hình
        input_data = pd.DataFrame({
            'Năm sản xuất': [year],
            'Số km đã đi': [km_driven],
            'Kiểu dáng': [car_type],
            'Xuất xứ': [origin],
            'Hộp số': [gearbox],
            'Nhiên liệu': [fuel]
        })
        
        prediction = model.predict(input_data)
        result.set(f"Giá dự đoán: {prediction[0]:,.2f} VND")
    except ValueError as e:
        messagebox.showerror("Lỗi", str(e))
    except Exception as e:
        messagebox.showerror("Lỗi", str(e))

# Tạo giao diện Tkinter
root = tk.Tk()
root.title("Car_Predict_HoangHaiDang")

# Nhãn và ô nhập liệu
tk.Label(root, text="Năm sản xuất:").grid(row=0, column=0, padx=10, pady=5)
year_entry = tk.Entry(root)
year_entry.grid(row=0, column=1, padx=10, pady=5)

tk.Label(root, text="Số km đã đi:").grid(row=1, column=0, padx=10, pady=5)
km_driven_entry = tk.Entry(root)
km_driven_entry.grid(row=1, column=1, padx=10, pady=5)

tk.Label(root, text="Kiểu dáng:").grid(row=2, column=0, padx=10, pady=5)
car_type_combobox = ttk.Combobox(root, values=['Sedan', 'SUV', 'MPV', 'Pick-upTruck', 'Hatchback', 'Convertible', 'CUV', 'Coupe', 'Van/Minivan', 'Đãquasửdụng', 'SportCar', 'Truck'], state='readonly')
car_type_combobox.grid(row=2, column=1, padx=10, pady=5)

tk.Label(root, text="Xuất xứ:").grid(row=3, column=0, padx=10, pady=5)
origin_combobox = ttk.Combobox(root, values=['Trongnước', 'Nhậpkhẩu'], state='readonly')
origin_combobox.grid(row=3, column=1, padx=10, pady=5)

tk.Label(root, text="Hộp số:").grid(row=4, column=0, padx=10, pady=5)
gearbox_combobox = ttk.Combobox(root, values=['Sốtựđộng', 'Sốtay', 'Sốhỗnhợp'], state='readonly')
gearbox_combobox.grid(row=4, column=1, padx=10, pady=5)

tk.Label(root, text="Nhiên liệu:").grid(row=5, column=0, padx=10, pady=5)
fuel_combobox = ttk.Combobox(root, values=['Xăng', 'Diesel', 'Loạikhác'], state='readonly')
fuel_combobox.grid(row=5, column=1, padx=10, pady=5)

# Nút dự đoán
tk.Button(root, text="Dự đoán", command=predict).grid(row=6, column=0, columnspan=2, pady=10)

# Nút thoát chương trình
tk.Button(root, text="Thoát", command=root.quit).grid(row=7, column=0, columnspan=2, pady=10)

# Hiển thị kết quả
result = tk.StringVar()
tk.Label(root, textvariable=result).grid(row=8, column=0, columnspan=2, pady=10)

# Chạy giao diện
root.mainloop()

# %% [markdown]
# # test

# %%
import pandas as pd

# Định nghĩa dữ liệu đầu vào (cần phải đúng định dạng như khi huấn luyện)
input_data = pd.DataFrame({
    'Năm sản xuất': [2018],
    'Số km đã đi': [30000],
    'Kiểu dáng': ['Sedan'],
    'Xuất xứ': ['Nhậpkhẩu'],
    'Hộp số': ['Sốtựđộng'],
    'Nhiên liệu': ['Xăng']
})

# Dự đoán giá
predicted_price = pipeline.predict(input_data)
formatted_price = format(predicted_price[0], ",.0f")  # Định dạng số với dấu "," phân cách hàng nghìn
print("Giá xe dự đoán:", formatted_price,"VND")
# Out:
# Giá xe dự đoán: 685,186,818 VND

# %%
import pandas as pd

# Đọc dữ liệu
data = pd.read_csv("data_processed1.csv")

# Xem các giá trị duy nhất của các cột phân loại
print("Các giá trị duy nhất của cột 'Kiểu dáng':")
print(data['Kiểu dáng'].unique())
print("-"*70)
print("Các giá trị duy nhất của cột 'Xuất xứ':")
print(data['Xuất xứ'].unique())
print("-"*70)
print("Các giá trị duy nhất của cột 'Hộp số':")
print(data['Hộp số'].unique())
print("-"*70)
print("Các giá trị duy nhất của cột 'Nhiên liệu':")
print(data['Nhiên liệu'].unique())
print("-"*70)
print("Các giá trị duy nhất của cột 'Năm sản xuất':")
print(data['Năm sản xuất'].unique())
# Out:
# Các giá trị duy nhất của cột 'Kiểu dáng':
# ['Sedan' 'SUV' 'MPV' 'Pick-upTruck' 'Hatchback' 'Convertible' 'CUV'
#  'Coupe' 'Van/Minivan' 'SportCar' 'Truck']
# ----------------------------------------------------------------------
# Các giá trị duy nhất của cột 'Xuất xứ':
# ['Trongnước' 'Nhậpkhẩu']
# ----------------------------------------------------------------------
# Các giá trị duy nhất của cột 'Hộp số':
# ['Sốtựđộng' 'Sốtay' 'Sốhỗnhợp']
# ----------------------------------------------------------------------
# Các giá trị duy nhất của cột 'Nhiên liệu':
# ['Xăng' 'Diesel' 'Loạikhác']
# ----------------------------------------------------------------------
# Các giá trị duy nhất của cột 'Năm sản xuất':
# [2016 2021 2009 2018 2015 2017 2013 2020 2019 2012 2010 2022 2011 2005
#  2008 2014 2006 2004 2007 1987 2001 2003 2002 1996 1993 1995]

# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# Định nghĩa pipeline như đã làm trước đây
categorical_cols = ['Năm sản xuất', 'Kiểu dáng', 'Xuất xứ', 'Hộp số', 'Nhiên liệu']

# Truy xuất OneHotEncoder từ pipeline
encoder = pipeline.named_steps['preprocessor'].named_transformers_['cat'].named_steps['onehot']

# Truy xuất các giá trị phân loại đã được huấn luyện
encoded_categories = encoder.categories_

# Tạo một dictionary để hiển thị các giá trị phân loại đã được huấn luyện
category_dict = {categorical_cols[i]: encoded_categories[i] for i in range(len(categorical_cols))}

# Hiển thị các giá trị phân loại đã được huấn luyện
for col, values in category_dict.items():
    print(f"{col}: {values}")
# Out:
# Năm sản xuất: [1987 1993 1995 1996 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011
#  2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022]
# Kiểu dáng: ['CUV' 'Convertible' 'Coupe' 'Hatchback' 'MPV' 'Pick-upTruck' 'SUV'
#  'Sedan' 'SportCar' 'Truck' 'Van/Minivan']
# Xuất xứ: ['Nhậpkhẩu' 'Trongnước']
# Hộp số: ['Sốhỗnhợp' 'Sốtay' 'Sốtựđộng']
# Nhiên liệu: ['Diesel' 'Loạikhác' 'Xăng']

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Đọc dữ liệu
data = pd.read_csv("data_processed1.csv")

# Phát hiện và xử lý ngoại lệ
Q1 = data['Giá'].quantile(0.3)
Q3 = data['Giá'].quantile(0.66)
IQR = Q3 - Q1
lower_bound = Q1 - 1.9 * IQR
upper_bound = Q3 + 0.9 * IQR

# Thay thế ngoại lệ bằng giá trị trung vị của biến
data['Giá'] = data['Giá'].apply(lambda x: x if lower_bound <= x <= upper_bound else data['Giá'].median())

# Tách biến đặc trưng và biến mục tiêu
X = data.drop(columns='Giá')
y = data['Giá']

# Thêm 'Năm sản xuất' vào các cột số
numerical_cols = ['Số km đã đi', 'Năm sản xuất']
categorical_cols = ['Kiểu dáng', 'Xuất xứ', 'Hộp số', 'Nhiên liệu']


# Tiền xử lý cho dữ liệu số
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# Tiền xử lý cho dữ liệu phân loại
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])


# Gộp tiền xử lý cho dữ liệu số và phân loại
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])




# Định nghĩa mô hình
model = RandomForestRegressor(random_state=10)

# Tạo pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('model', model)])

# Chia dữ liệu thành tập huấn luyện và kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.18   , random_state=74          )

# Huấn luyện mô hình
pipeline.fit(X_train, y_train)

# Dự đoán
y_pred = pipeline.predict(X_test)

# Đánh giá mô hình
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Absolute Error (MAE): 33858708.52017291
# Mean Squared Error (MSE): 4645004264212674.0
# Root Mean Squared Error (RMSE): 68154268.12909573
# R^2 Score: 0.8654045576365712
